# %%
import random 

def computador_advinha():
    max= 100
    min = 0 
    tent = 0 
    resposta = ""
    print("Pense em um número entre 0 e 100, e o computador tentará adivinhar!")
    
    while resposta != "acertou":  
 
        num= (max + min) // 2
        tent= tent+1 
        print (f"o palpite do computador é {num}")
        
        resposta= input(" Responde com maior, menor ou acertou")
        
        if resposta == "maior":
         min= num +1 
         print (f" o numero é maior tente novamente")
        elif resposta== "menor":
            max= num -1
            print (f"o numero  é menor tente novamente")
        elif resposta == "acertou":
            print (f" O numero que pensou é {num}, acertei  em {tent-1} tentativas")
        else:
           print ("resposta nao foi valida ")





def pessoa_advinha():
    num=random.randrange(1,101)
    tentativas=1
    resposta = ()
    while resposta != num:
        resposta= (int(input(" Introduza o numero")))
        tentativas= tentativas +1 
        if resposta > num:
            print("O número que pensei é menor!!")
        elif resposta < num:
            print("O número que pensei é maior!!")
        else:
            print(f"Parabéns! o numero era {num}! Acertou em  {tentativas} tentativas")



    
def menu():
    print("Escolha um modo de jogo:")
    print("1. Você pensa num número e o computador tenta adivinhar")
    print("2. Computador pensa num número e você tenta adivinhar")
    modo = input(" 1»» tenta advinhar 2»»» computador advinha Digite 1 ou 2: ").strip()
    if modo == "1":
        pessoa_advinha()
    elif modo == "2":
        computador_advinha()
    else:
        print("Modo de jogo não encontrado....")



menu()
# Out:
# Escolha um modo de jogo:
# 1. Você pensa num número e o computador tenta adivinhar
# 2. Computador pensa num número e você tenta adivinhar
# O número que pensei é menor!!
# O número que pensei é maior!!
# O número que pensei é maior!!
# O número que pensei é menor!!
# O número que pensei é menor!!
# Parabéns! o numero era 39! Acertou em  7 tentativas
